# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 618

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
 description = city_weather["weather"]["description"]
       "Current Description": description})
            new_column_order= ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sao joao da barra
# Processing Record 2 of Set 1 | cabo san lucas
# Processing Record 3 of Set 1 | raudeberg
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | diego de almagro
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | varhaug
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | wakefield
# Processing Record 12 of Set 1 | dok kham tai
# Processing Record 13 of Set 1 | werder
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | tabou
# Processing Record 16 of Set 1 | tilichiki
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | taoudenni
# Processing Record 21 of Set 1 | bekhteyevka
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | lorengau
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | taburao
# City not found. Skipping...
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | lavrentiya
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | paamiut
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | lompoc
# Processing Record 40 of Set 1 | cabedelo
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | bikaner
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | mount isa
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | progreso
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | kovdor
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | nemuro
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | lysva
# Processing Record 5 of Set 2 | walvis bay
# Processing Record 6 of Set 2 | privolzhskiy
# Processing Record 7 of Set 2 | buriti bravo
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | hasaki
# Processing Record 10 of Set 2 | zhigansk
# Processing Record 11 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 2 | anadyr
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | tuatapere
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | alofi
# Processing Record 18 of Set 2 | vallenar
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | sakakah
# Processing Record 21 of Set 2 | san vicente
# Processing Record 22 of Set 2 | sheopur
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | alto piquiri
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | ribas do rio pardo
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | high level
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | tessalit
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | santa maria
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | quatre cocos
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | mehamn
# Processing Record 40 of Set 2 | baghdad
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | makung
# City not found. Skipping...
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | shevchenko
# Processing Record 46 of Set 2 | kununurra
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | robertsport
# Processing Record 49 of Set 2 | fortuna
# Processing Record 50 of Set 2 | santa fe
# Processing Record 1 of Set 3 | vysha
# Processing Record 2 of Set 3 | namibe
# Processing Record 3 of Set 3 | sao jose da coroa grande
# Processing Record 4 of Set 3 | nador
# Processing Record 5 of Set 3 | manokwari
# Processing Record 6 of Set 3 | aksarka
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | tekkalakota
# City not found. Skipping...
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | det udom
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | haines junction
# Processing Record 14 of Set 3 | bull savanna
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 3 | sept-iles
# Processing Record 18 of Set 3 | nelson bay
# Processing Record 19 of Set 3 | tuktoyaktuk
# Processing Record 20 of Set 3 | morros
# Processing Record 21 of Set 3 | flinders
# Processing Record 22 of Set 3 | longido
# Processing Record 23 of Set 3 | nokaneng
# Processing Record 24 of Set 3 | san andres
# Processing Record 25 of Set 3 | roald
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | vestmanna
# Processing Record 28 of Set 3 | chaozhou
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | faya
# Processing Record 33 of Set 3 | skjervoy
# Processing Record 34 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | port hardy
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | dickinson
# Processing Record 39 of Set 3 | bakel
# Processing Record 40 of Set 3 | westport
# Processing Record 41 of Set 3 | manyana
# Processing Record 42 of Set 3 | antalaha
# Processing Record 43 of Set 3 | tazovskiy
# Processing Record 44 of Set 3 | lamu
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | belmonte
# Processing Record 47 of Set 3 | pyryatyn
# Processing Record 48 of Set 3 | krasnoselkup
# Processing Record 49 of Set 3 | arlit
# Processing Record 50 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 4 | ponta delgada
# Processing Record 2 of Set 4 | trelew
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | lacey
# Processing Record 6 of Set 4 | mackay
# Processing Record 7 of Set 4 | dunda
# Processing Record 8 of Set 4 | ventspils
# Processing Record 9 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 4 | taltal
# Processing Record 11 of Set 4 | te anau
# Processing Record 12 of Set 4 | bengkulu
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | yenagoa
# Processing Record 15 of Set 4 | sooke
# Processing Record 16 of Set 4 | slave lake
# Processing Record 17 of Set 4 | svetlaya
# Processing Record 18 of Set 4 | ulaangom
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | laguna de perlas
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | kloulklubed
# Processing Record 23 of Set 4 | himora
# City not found. Skipping...
# Processing Record 24 of Set 4 | katangli
# Processing Record 25 of Set 4 | malakal
# Processing Record 26 of Set 4 | port lincoln
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | gubkinskiy
# Processing Record 30 of Set 4 | yerbogachen
# Processing Record 31 of Set 4 | ambon
# Processing Record 32 of Set 4 | havoysund
# Processing Record 33 of Set 4 | russell
# Processing Record 34 of Set 4 | bandrele
# Processing Record 35 of Set 4 | shimoda
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | puerto carreno
# Processing Record 39 of Set 4 | mporokoso
# Processing Record 40 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 4 | chuy
# Processing Record 42 of Set 4 | marovoay
# Processing Record 43 of Set 4 | coquimbo
# Processing Record 44 of Set 4 | mingshui
# Processing Record 45 of Set 4 | olafsvik
# Processing Record 46 of Set 4 | moctezuma
# Processing Record 47 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 48 of Set 4 | la teste-de-buch
# Processing Record 49 of Set 4 | shevchenkove
# Processing Record 50 of Set 4 | acajutla
# Processing Record 1 of Set 5 | taguatinga
# Processing Record 2 of Set 5 | vila velha
# Processing Record 3 of Set 5 | caravelas
# Processing Record 4 of Set 5 | bonthe
# Processing Record 5 of Set 5 | avera
# Processing Record 6 of Set 5 | sobolevo
# Processing Record 7 of Set 5 | payakumbuh
# Processing Record 8 of Set 5 | zherdevka
# Processing Record 9 of Set 5 | damghan
# Processing Record 10 of Set 5 | chipurupalle
# Processing Record 11 of Set 5 | talnakh
# Processing Record 12 of Set 5 | vestmannaeyjar
# Processing Record 13 of Set 5 | pascagoula
# Processing Record 14 of Set 5 | lebu
# Processing Record 15 of Set 5 | urumqi
# Processing Record 16 of Set 5 | bertoua
# Processing Record 17 of Set 5 | poum
# Processing Record 18 of Set 5 | portel
# Processing Record 19 of Set 5 | richards bay
# Processing Record 20 of Set 5 | omsukchan
# Processing Record 21 of Set 5 | arys
# Processing Record 22 of Set 5 | alice springs
# Processing Record 23 of Set 5 | hoquiam
# Processing Record 24 of Set 5 | hobart
# Processing Record 25 of Set 5 | mogilno
# Processing Record 26 of Set 5 | kudahuvadhoo
# Processing Record 27 of Set 5 | axim
# Processing Record 28 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 5 | georgetown
# Processing Record 30 of Set 5 | houston
# Processing Record 31 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 5 | norman wells
# Processing Record 33 of Set 5 | buta
# Processing Record 34 of Set 5 | itapirapua
# Processing Record 35 of Set 5 | dunedin
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | comodoro rivadavia
# Processing Record 38 of Set 5 | morshansk
# Processing Record 39 of Set 5 | healdsburg
# Processing Record 40 of Set 5 | carnarvon
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | klaksvik
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | kruisfontein
# Processing Record 45 of Set 5 | west bay
# Processing Record 46 of Set 5 | hambantota
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 5 | jimenez
# Processing Record 50 of Set 5 | yumen
# Processing Record 1 of Set 6 | bambous virieux
# Processing Record 2 of Set 6 | bethel
# Processing Record 3 of Set 6 | horta
# Processing Record 4 of Set 6 | kungurtug
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | dzerzhinsk
# Processing Record 7 of Set 6 | eureka
# Processing Record 8 of Set 6 | nhulunbuy
# Processing Record 9 of Set 6 | yanji
# Processing Record 10 of Set 6 | los llanos de aridane
# Processing Record 11 of Set 6 | maarianhamina
# Processing Record 12 of Set 6 | bandarbeyla
# Processing Record 13 of Set 6 | mpulungu
# Processing Record 14 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 6 | nara
# Processing Record 16 of Set 6 | vidim
# Processing Record 17 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 6 | katsuura
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | general roca
# Processing Record 21 of Set 6 | buala
# Processing Record 22 of Set 6 | yulara
# Processing Record 23 of Set 6 | pevek
# Processing Record 24 of Set 6 | saint anthony
# Processing Record 25 of Set 6 | kodiak
# Processing Record 26 of Set 6 | bryant
# Processing Record 27 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 6 | kolno
# Processing Record 29 of Set 6 | kangaatsiaq
# Processing Record 30 of Set 6 | sagarejo
# Processing Record 31 of Set 6 | deputatskiy
# Processing Record 32 of Set 6 | viedma
# Processing Record 33 of Set 6 | goderich
# Processing Record 34 of Set 6 | guadalupe y calvo
# Processing Record 35 of Set 6 | ahipara
# Processing Record 36 of Set 6 | linxia
# Processing Record 37 of Set 6 | north bend
# Processing Record 38 of Set 6 | champerico
# Processing Record 39 of Set 6 | wanlaweyn
# Processing Record 40 of Set 6 | belaya gora
# Processing Record 41 of Set 6 | xiaoweizhai
# Processing Record 42 of Set 6 | ixtapa
# Processing Record 43 of Set 6 | porbandar
# Processing Record 44 of Set 6 | la asuncion
# Processing Record 45 of Set 6 | cayenne
# Processing Record 46 of Set 6 | marshall
# Processing Record 47 of Set 6 | nanortalik
# Processing Record 48 of Set 6 | birjand
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | erenhot
# Processing Record 1 of Set 7 | ormara
# Processing Record 2 of Set 7 | oussouye
# Processing Record 3 of Set 7 | laredo
# Processing Record 4 of Set 7 | airai
# Processing Record 5 of Set 7 | asau
# Processing Record 6 of Set 7 | padang
# Processing Record 7 of Set 7 | ilulissat
# Processing Record 8 of Set 7 | karonga
# Processing Record 9 of Set 7 | acapulco
# Processing Record 10 of Set 7 | lazaro cardenas
# Processing Record 11 of Set 7 | aguimes
# Processing Record 12 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 7 | strezhevoy
# Processing Record 14 of Set 7 | aloleng
# Processing Record 15 of Set 7 | sitka
# Processing Record 16 of Set 7 | kingseat
# Processing Record 17 of Set 7 | hovd
# Processing Record 18 of Set 7 | sabang
# Processing Record 19 of Set 7 | linares
# Processing Record 20 of Set 7 | abu dhabi
# Processing Record 21 of Set 7 | mae hong son
# Processing Record 22 of Set 7 | pangnirtung
# Processing Record 23 of Set 7 | itarema
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | sambava
# Processing Record 26 of Set 7 | coahuayana
# Processing Record 27 of Set 7 | jalu
# Processing Record 28 of Set 7 | portoferraio
# Processing Record 29 of Set 7 | aklavik
# Processing Record 30 of Set 7 | chara
# Processing Record 31 of Set 7 | iquique
# Processing Record 32 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 7 | aksehir
# Processing Record 34 of Set 7 | praia
# Processing Record 35 of Set 7 | ewa beach
# Processing Record 36 of Set 7 | aykhal
# Processing Record 37 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 7 | verkhnyaya inta
# Processing Record 39 of Set 7 | macusani
# Processing Record 40 of Set 7 | okha
# Processing Record 41 of Set 7 | adrar
# Processing Record 42 of Set 7 | srednekolymsk
# Processing Record 43 of Set 7 | waddan
# Processing Record 44 of Set 7 | changji
# Processing Record 45 of Set 7 | tame
# Processing Record 46 of Set 7 | leningradskiy
# Processing Record 47 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 7 | vanavara
# Processing Record 49 of Set 7 | poltavka
# Processing Record 50 of Set 7 | meulaboh
# Processing Record 1 of Set 8 | mosetse
# Processing Record 2 of Set 8 | kirovskiy
# Processing Record 3 of Set 8 | sibolga
# Processing Record 4 of Set 8 | nuuk
# Processing Record 5 of Set 8 | port blair
# Processing Record 6 of Set 8 | broken hill
# Processing Record 7 of Set 8 | cairns
# Processing Record 8 of Set 8 | victoria
# Processing Record 9 of Set 8 | bowen
# Processing Record 10 of Set 8 | provideniya
# Processing Record 11 of Set 8 | golden
# Processing Record 12 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 13 of Set 8 | mercedes
# Processing Record 14 of Set 8 | bathsheba
# Processing Record 15 of Set 8 | urengoy
# Processing Record 16 of Set 8 | bouca
# Processing Record 17 of Set 8 | tavda
# Processing Record 18 of Set 8 | mastic beach
# Processing Record 19 of Set 8 | la ronge
# Processing Record 20 of Set 8 | codrington
# Processing Record 21 of Set 8 | halifax
# Processing Record 22 of Set 8 | yeppoon
# Processing Record 23 of Set 8 | guarapari
# Processing Record 24 of Set 8 | dawlatabad
# Processing Record 25 of Set 8 | yuci
# Processing Record 26 of Set 8 | camacha
# Processing Record 27 of Set 8 | grand gaube
# Processing Record 28 of Set 8 | chapais
# Processing Record 29 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 8 | rietavas
# Processing Record 32 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 33 of Set 8 | beringovskiy
# Processing Record 34 of Set 8 | gladstone
# Processing Record 35 of Set 8 | fairbanks
# Processing Record 36 of Set 8 | augusto correa
# Processing Record 37 of Set 8 | manzhouli
# Processing Record 38 of Set 8 | misratah
# Processing Record 39 of Set 8 | bac lieu
# Processing Record 40 of Set 8 | sola
# Processing Record 41 of Set 8 | lagoa
# Processing Record 42 of Set 8 | bastia
# Processing Record 43 of Set 8 | praia da vitoria
# Processing Record 44 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 45 of Set 8 | chiang klang
# Processing Record 46 of Set 8 | oktyabrskoye
# Processing Record 47 of Set 8 | kieta
# Processing Record 48 of Set 8 | konstantinovskiy
# Processing Record 49 of Set 8 | anzio
# Processing Record 50 of Set 8 | thunder bay
# Processing Record 1 of Set 9 | la libertad
# Processing Record 2 of Set 9 | emilio carranza
# Processing Record 3 of Set 9 | honiara
# Processing Record 4 of Set 9 | ayagoz
# Processing Record 5 of Set 9 | fare
# Processing Record 6 of Set 9 | mopipi
# Processing Record 7 of Set 9 | xirokambos
# City not found. Skipping...
# Processing Record 8 of Set 9 | oksfjord
# Processing Record 9 of Set 9 | kabare
# Processing Record 10 of Set 9 | fallon
# Processing Record 11 of Set 9 | southern pines
# Processing Record 12 of Set 9 | lata
# Processing Record 13 of Set 9 | daru
# Processing Record 14 of Set 9 | okhotsk
# Processing Record 15 of Set 9 | vredendal
# Processing Record 16 of Set 9 | galveston
# Processing Record 17 of Set 9 | yantal
# Processing Record 18 of Set 9 | umm lajj
# Processing Record 19 of Set 9 | grafton
# Processing Record 20 of Set 9 | almunecar
# Processing Record 21 of Set 9 | ostrovnoy
# Processing Record 22 of Set 9 | rumford
# Processing Record 23 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 24 of Set 9 | constantine
# Processing Record 25 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 9 | rognan
# Processing Record 27 of Set 9 | pandamatenga
# Processing Record 28 of Set 9 | narsaq
# Processing Record 29 of Set 9 | orissaare
# Processing Record 30 of Set 9 | rodez
# Processing Record 31 of Set 9 | honningsvag
# Processing Record 32 of Set 9 | mirnyy
# Processing Record 33 of Set 9 | kotido
# Processing Record 34 of Set 9 | san-pedro
# Processing Record 35 of Set 9 | nazarovo
# Processing Record 36 of Set 9 | amarwara
# Processing Record 37 of Set 9 | lodja
# Processing Record 38 of Set 9 | porto novo
# Processing Record 39 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 9 | ondjiva
# Processing Record 41 of Set 9 | alamosa
# Processing Record 42 of Set 9 | inuvik
# Processing Record 43 of Set 9 | esso
# Processing Record 44 of Set 9 | inhambane
# Processing Record 45 of Set 9 | vadso
# Processing Record 46 of Set 9 | ancud
# Processing Record 47 of Set 9 | dalianwan
# Processing Record 48 of Set 9 | kjollefjord
# Processing Record 49 of Set 9 | kalakamati
# Processing Record 50 of Set 9 | thaton
# Processing Record 1 of Set 10 | isla vista
# Processing Record 2 of Set 10 | tokur
# Processing Record 3 of Set 10 | sao filipe
# Processing Record 4 of Set 10 | shimoga
# Processing Record 5 of Set 10 | shihezi
# Processing Record 6 of Set 10 | zhezkazgan
# Processing Record 7 of Set 10 | douglas
# Processing Record 8 of Set 10 | muroto
# Processing Record 9 of Set 10 | iringa
# Processing Record 10 of Set 10 | la plata
# Processing Record 11 of Set 10 | santa isabel
# Processing Record 12 of Set 10 | hue
# Processing Record 13 of Set 10 | moerai
# Processing Record 14 of Set 10 | ariquemes
# Processing Record 15 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 10 | omboue
# Processing Record 17 of Set 10 | suez
# Processing Record 18 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 10 | coleraine
# Processing Record 20 of Set 10 | peniche
# Processing Record 21 of Set 10 | ust-maya
# Processing Record 22 of Set 10 | jaguaruana
# Processing Record 23 of Set 10 | kirksville
# Processing Record 24 of Set 10 | plerin
# Processing Record 25 of Set 10 | palmer
# Processing Record 26 of Set 10 | krasnyy yar
# Processing Record 27 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 28 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 29 of Set 10 | ginir
# Processing Record 30 of Set 10 | seminole
# Processing Record 31 of Set 10 | balurghat
# Processing Record 32 of Set 10 | lubben
# Processing Record 33 of Set 10 | kings mountain
# Processing Record 34 of Set 10 | ishigaki
# Processing Record 35 of Set 10 | dauphin
# Processing Record 36 of Set 10 | sorland
# Processing Record 37 of Set 10 | pacific grove
# Processing Record 38 of Set 10 | yurginskoye
# Processing Record 39 of Set 10 | sinnamary
# Processing Record 40 of Set 10 | slawno
# Processing Record 41 of Set 10 | road town
# Processing Record 42 of Set 10 | choctaw
# Processing Record 43 of Set 10 | islamkot
# Processing Record 44 of Set 10 | majene
# Processing Record 45 of Set 10 | matamoros
# Processing Record 46 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 10 | yar-sale
# Processing Record 48 of Set 10 | baykit
# Processing Record 49 of Set 10 | kosh-agach
# Processing Record 50 of Set 10 | grand-santi
# Processing Record 1 of Set 11 | tres arroyos
# Processing Record 2 of Set 11 | pochutla
# Processing Record 3 of Set 11 | lasa
# Processing Record 4 of Set 11 | tabuk
# Processing Record 5 of Set 11 | faranah
# Processing Record 6 of Set 11 | edd
# Processing Record 7 of Set 11 | nileshwar
# Processing Record 8 of Set 11 | atar
# Processing Record 9 of Set 11 | diamantino
# Processing Record 10 of Set 11 | najran
# Processing Record 11 of Set 11 | kholodnyy
# Processing Record 12 of Set 11 | villa guerrero
# Processing Record 13 of Set 11 | kazachinskoye
# Processing Record 14 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 11 | kamyshlov
# Processing Record 16 of Set 11 | ati
# Processing Record 17 of Set 11 | qaqortoq
# Processing Record 18 of Set 11 | mikkeli
# Processing Record 19 of Set 11 | boldumsaz
# Processing Record 20 of Set 11 | marsh harbour
# Processing Record 21 of Set 11 | sentjur
# Processing Record 22 of Set 11 | nyurba
# Processing Record 23 of Set 11 | ajaccio
# Processing Record 24 of Set 11 | san quintin
# Processing Record 25 of Set 11 | panguna
# Processing Record 26 of Set 11 | bosaso
# Processing Record 27 of Set 11 | fuerte olimpo
# Processing Record 28 of Set 11 | lazarev
# Processing Record 29 of Set 11 | sur
# Processing Record 30 of Set 11 | bam
# Processing Record 31 of Set 11 | chimbote
# Processing Record 32 of Set 11 | buin
# Processing Record 33 of Set 11 | yuzawa
# Processing Record 34 of Set 11 | prince george
# Processing Record 35 of Set 11 | sovetskiy
# Processing Record 36 of Set 11 | tiarei
# Processing Record 37 of Set 11 | coracora
# Processing Record 38 of Set 11 | glendive
# Processing Record 39 of Set 11 | abong mbang
# Processing Record 40 of Set 11 | carutapera
# Processing Record 41 of Set 11 | yuli
# Processing Record 42 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 11 | parfenyevo
# Processing Record 44 of Set 11 | hamina
# Processing Record 45 of Set 11 | inirida
# Processing Record 46 of Set 11 | severobaykalsk
# Processing Record 47 of Set 11 | floro
# Processing Record 48 of Set 11 | stephenville crossing
# Processing Record 49 of Set 11 | akhaldaba
# Processing Record 50 of Set 11 | chabahar
# Processing Record 1 of Set 12 | mugur-aksy
# Processing Record 2 of Set 12 | husavik
# Processing Record 3 of Set 12 | berlevag
# Processing Record 4 of Set 12 | magetan
# City not found. Skipping...
# Processing Record 5 of Set 12 | winslow
# Processing Record 6 of Set 12 | solnechnyy
# Processing Record 7 of Set 12 | stornoway
# Processing Record 8 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 9 of Set 12 | jiuquan
# Processing Record 10 of Set 12 | ichhawar
# Processing Record 11 of Set 12 | candolim
# Processing Record 12 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | ocos
# Processing Record 14 of Set 12 | agadez
# Processing Record 15 of Set 12 | vanino
# Processing Record 16 of Set 12 | vargashi
# Processing Record 17 of Set 12 | amberley
# Processing Record 18 of Set 12 | aquiraz
# Processing Record 19 of Set 12 | huicungo
# Processing Record 20 of Set 12 | saint-augustin
# Processing Record 21 of Set 12 | lake jackson
# Processing Record 22 of Set 12 | saldanha
# Processing Record 23 of Set 12 | nantucket
# Processing Record 24 of Set 12 | nankana sahib
# Processing Record 25 of Set 12 | shawnee
# Processing Record 26 of Set 12 | samarai
# Processing Record 27 of Set 12 | ambilobe
# Processing Record 28 of Set 12 | kotma
# Processing Record 29 of Set 12 | rio gallegos
# Processing Record 30 of Set 12 | cockburn town
# Processing Record 31 of Set 12 | sadiqabad
# Processing Record 32 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 12 | tsaratanana
# Processing Record 34 of Set 12 | golega
# Processing Record 35 of Set 12 | cangucu
# Processing Record 36 of Set 12 | greenville
# Processing Record 37 of Set 12 | mul
# Processing Record 38 of Set 12 | qostanay
# Processing Record 39 of Set 12 | tiznit
# Processing Record 40 of Set 12 | bud
# Processing Record 41 of Set 12 | dobryatino
# Processing Record 42 of Set 12 | voznesenye
# Processing Record 43 of Set 12 | tutoia
# Processing Record 44 of Set 12 | colares
# Processing Record 45 of Set 12 | saint-joseph
# Processing Record 46 of Set 12 | mykolayiv
# Processing Record 47 of Set 12 | alyangula
# Processing Record 48 of Set 12 | bereda
# Processing Record 49 of Set 12 | tortoli
# Processing Record 50 of Set 12 | pringsewu
# Processing Record 1 of Set 13 | mildura
# Processing Record 2 of Set 13 | guerrero negro
# Processing Record 3 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 13 | chissamba
# Processing Record 5 of Set 13 | saint-georges
# Processing Record 6 of Set 13 | tomatlan
# Processing Record 7 of Set 13 | batagay-alyta
# Processing Record 8 of Set 13 | amahai
# Processing Record 9 of Set 13 | visnes
# Processing Record 10 of Set 13 | hami
# Processing Record 11 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 13 | cap-aux-meules
# Processing Record 13 of Set 13 | hualmay
# Processing Record 14 of Set 13 | sale
# Processing Record 15 of Set 13 | bhor
# Processing Record 16 of Set 13 | trujillo
# Processing Record 17 of Set 13 | oranjemund
# Processing Record 18 of Set 13 | kijang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sao Joao Da Barra -21.6403  -41.0511     73.49        85          31
# 1     Cabo San Lucas  22.8909 -109.9124     95.61        55          20
# 2          Raudeberg  61.9875    5.1352     50.67        80         100
# 3          Hithadhoo  -0.6000   73.0833     80.83        75         100
# 4       Saint George  37.1041 -113.5841     92.43        39           0
# 5   Diego De Almagro -26.3667  -70.0500     69.53        29           9
# 6          Jamestown  42.0970  -79.2353     80.02        46         100
# 7            Varhaug  58.6147    5.6457     52.48        77          69
# 8          Wakefield  53.6809   -1.4990     60.64        92          98
# 9       Dok Kham Tai  19.1624   99.9934     74.14        91          94
#
#    Wind Speed Country                 Date
# 0       10.98      BR  2022-07-26 21:14:52
# 1       12.66      MX  2022-07-26 21:14:25
# 2       18.41      NO  2022-07-26 21:14:52
# 3       13.58      MV  2022-07-26 21:14:53
# 4        5.01      US  2022-07-26 21:11:02
# 5        5.82      CL  2022-07-26 21:14:54
# 6        8.05      US  2022-07-26 21:12:26
# 7       28.52      NO  2022-07-26 21:14:54
# 8        4.29      GB  2022-07-26 21:14:55
# 9        2.39      TH  2022-07-26 21:14:55

# %%
new_column_order= ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0  Sao Joao Da Barra      BR  2022-07-26 21:14:52 -21.6403  -41.0511
# 1     Cabo San Lucas      MX  2022-07-26 21:14:25  22.8909 -109.9124
# 2          Raudeberg      NO  2022-07-26 21:14:52  61.9875    5.1352
# 3          Hithadhoo      MV  2022-07-26 21:14:53  -0.6000   73.0833
# 4       Saint George      US  2022-07-26 21:11:02  37.1041 -113.5841
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     73.49        85          31       10.98
# 1     95.61        55          20       12.66
# 2     50.67        80         100       18.41
# 3     80.83        75         100       13.58
# 4     92.43        39           0        5.01

# %%
# Create the output file (CSV)
output_data_file = "weather_data/cities.csv"
#Export the City_Data into CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extraact relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module
import time

# Get today's date in seconds
today = time.time()
today
# Out:
# 1658871007.3040829

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Tilichiki
# Country                        RU
# Date          2022-07-26 21:14:56
# Lat                       60.4667
# Lng                         166.1
# Max Temp                    54.23
# Humidity                       71
# Cloudiness                    100
# Wind Speed                   4.54
# Name: 13, dtype: object

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 1  Cabo San Lucas      MX  2022-07-26 21:14:25  22.8909 -109.9124     95.61
# 2       Raudeberg      NO  2022-07-26 21:14:52  61.9875    5.1352     50.67
# 4    Saint George      US  2022-07-26 21:11:02  37.1041 -113.5841     92.43
# 6       Jamestown      US  2022-07-26 21:12:26  42.0970  -79.2353     80.02
# 7         Varhaug      NO  2022-07-26 21:14:54  58.6147    5.6457     52.48
#
#    Humidity  Cloudiness  Wind Speed
# 1        55          20       12.66
# 2        80         100       18.41
# 4        39           0        5.01
# 6        46         100        8.05
# 7        77          69       28.52

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
(_, _, r_value, p_value, _) = linregress(x_values, y_values)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# The p-value is: 0.000
# The r-value is: -0.691

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
(_, _, r_value, p_value, _) = linregress(x_values, y_values)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# The p-value is: 0.000
# The r-value is: 0.743

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
(_, _, r_value, p_value, _) = linregress(x_values, y_values)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# The p-value is: 0.013
# The r-value is: 0.125

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
(_, _, r_value, p_value, _) = linregress(x_values, y_values)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# The p-value is: 0.001
# The r-value is: -0.250

# %%
# Linear regression on the Southern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,15))

# %%
(_, _, r_value, p_value, _) = linregress(x_values, y_values)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# The p-value is: 0.549
# The r-value is: -0.030

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
(_, _, r_value, p_value, _) = linregress(x_values, y_values)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# The p-value is: 0.228
# The r-value is: 0.093

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
(_, _, r_value, p_value, _) = linregress(x_values, y_values)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# The p-value is: 0.986
# The r-value is: 0.001

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
(_, _, r_value, p_value, _) = linregress(x_values, y_values)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# The p-value is: 0.908
# The r-value is: -0.009

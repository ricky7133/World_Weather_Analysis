# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time

from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# %%
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_des = city_weather["weather"][0]["description"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Description": city_des,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | guane
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 1 | alice springs
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | belmonte
# Processing Record 13 of Set 1 | moose factory
# Processing Record 14 of Set 1 | posse
# Processing Record 15 of Set 1 | sibu
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | mollendo
# Processing Record 18 of Set 1 | osoyoos
# Processing Record 19 of Set 1 | nanpiao
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | weligama
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | lata
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | bud
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | solsvik
# City not found. Skipping...
# Processing Record 31 of Set 1 | halifax
# Processing Record 32 of Set 1 | aksu
# Processing Record 33 of Set 1 | nome
# Processing Record 34 of Set 1 | mitu
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | ilulissat
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | kwinana
# Processing Record 43 of Set 1 | ostrovnoy
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | grand forks
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | pangnirtung
# Processing Record 2 of Set 2 | luanda
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | marshall
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | biltine
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | san pedro
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | chernigovka
# Processing Record 12 of Set 2 | kilindoni
# Processing Record 13 of Set 2 | jamame
# Processing Record 14 of Set 2 | turmalina
# Processing Record 15 of Set 2 | orocue
# Processing Record 16 of Set 2 | praia da vitoria
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | yakeshi
# Processing Record 19 of Set 2 | cayenne
# Processing Record 20 of Set 2 | gat
# Processing Record 21 of Set 2 | tuatapere
# Processing Record 22 of Set 2 | sola
# Processing Record 23 of Set 2 | tiznit
# Processing Record 24 of Set 2 | kharan
# Processing Record 25 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | samarai
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | taltal
# Processing Record 30 of Set 2 | nanortalik
# Processing Record 31 of Set 2 | honiara
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | onokhoy
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | trelew
# Processing Record 36 of Set 2 | beyneu
# Processing Record 37 of Set 2 | meulaboh
# Processing Record 38 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | johor bahru
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | rocha
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | nikolskoye
# Processing Record 50 of Set 2 | chicama
# Processing Record 1 of Set 3 | lawton
# Processing Record 2 of Set 3 | komsomolskiy
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 3 | along
# Processing Record 8 of Set 3 | mecca
# Processing Record 9 of Set 3 | flinders
# Processing Record 10 of Set 3 | svetlaya
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | vila franca do campo
# Processing Record 13 of Set 3 | tessalit
# Processing Record 14 of Set 3 | lagos
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | victor harbor
# Processing Record 17 of Set 3 | amapa
# Processing Record 18 of Set 3 | srednekolymsk
# Processing Record 19 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 3 | talcahuano
# Processing Record 21 of Set 3 | oistins
# Processing Record 22 of Set 3 | boyolangu
# Processing Record 23 of Set 3 | abu samrah
# Processing Record 24 of Set 3 | parainen
# Processing Record 25 of Set 3 | lasa
# Processing Record 26 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 3 | faanui
# Processing Record 28 of Set 3 | mbala
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | batagay-alyta
# Processing Record 31 of Set 3 | vysotsk
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | bontang
# Processing Record 34 of Set 3 | tezu
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | houma
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | pontal do parana
# Processing Record 39 of Set 3 | urucara
# Processing Record 40 of Set 3 | goderich
# Processing Record 41 of Set 3 | kerzhenets
# City not found. Skipping...
# Processing Record 42 of Set 3 | merauke
# Processing Record 43 of Set 3 | killybegs
# Processing Record 44 of Set 3 | mataura
# Processing Record 45 of Set 3 | surt
# Processing Record 46 of Set 3 | haukipudas
# Processing Record 47 of Set 3 | kosikha
# Processing Record 48 of Set 3 | kavaratti
# Processing Record 49 of Set 3 | bilibino
# Processing Record 50 of Set 3 | eureka
# Processing Record 1 of Set 4 | upernavik
# Processing Record 2 of Set 4 | goure
# Processing Record 3 of Set 4 | olafsvik
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | plettenberg bay
# Processing Record 7 of Set 4 | egvekinot
# Processing Record 8 of Set 4 | davila
# Processing Record 9 of Set 4 | marsa matruh
# Processing Record 10 of Set 4 | gigmoto
# Processing Record 11 of Set 4 | ponta do sol
# Processing Record 12 of Set 4 | dicabisagan
# Processing Record 13 of Set 4 | rock springs
# Processing Record 14 of Set 4 | dali
# Processing Record 15 of Set 4 | liwale
# Processing Record 16 of Set 4 | whitehorse
# Processing Record 17 of Set 4 | pontianak
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | touros
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | la tuque
# Processing Record 22 of Set 4 | suratgarh
# Processing Record 23 of Set 4 | udachnyy
# Processing Record 24 of Set 4 | korla
# Processing Record 25 of Set 4 | pimentel
# Processing Record 26 of Set 4 | solnechnyy
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | lorengau
# Processing Record 29 of Set 4 | sitangkai
# Processing Record 30 of Set 4 | severo-kurilsk
# Processing Record 31 of Set 4 | leningradskiy
# Processing Record 32 of Set 4 | yuanping
# Processing Record 33 of Set 4 | hudson bay
# Processing Record 34 of Set 4 | hervey bay
# Processing Record 35 of Set 4 | porirua
# Processing Record 36 of Set 4 | batagay
# Processing Record 37 of Set 4 | kuusamo
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | inhambane
# Processing Record 41 of Set 4 | bukama
# Processing Record 42 of Set 4 | nhulunbuy
# Processing Record 43 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | mahibadhoo
# Processing Record 46 of Set 4 | iqaluit
# Processing Record 47 of Set 4 | avera
# Processing Record 48 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | koboko
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | sunland park
# Processing Record 3 of Set 5 | labuhan
# Processing Record 4 of Set 5 | mantua
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | kautokeino
# Processing Record 7 of Set 5 | lompoc
# Processing Record 8 of Set 5 | vestmannaeyjar
# Processing Record 9 of Set 5 | east london
# Processing Record 10 of Set 5 | kenscoff
# Processing Record 11 of Set 5 | keti bandar
# Processing Record 12 of Set 5 | evensk
# Processing Record 13 of Set 5 | coahuayana
# Processing Record 14 of Set 5 | bredasdorp
# Processing Record 15 of Set 5 | adrar
# Processing Record 16 of Set 5 | kabanjahe
# Processing Record 17 of Set 5 | den helder
# Processing Record 18 of Set 5 | sorland
# Processing Record 19 of Set 5 | tautira
# Processing Record 20 of Set 5 | berlevag
# Processing Record 21 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 22 of Set 5 | mbandaka
# Processing Record 23 of Set 5 | jalu
# Processing Record 24 of Set 5 | chapais
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | yenagoa
# Processing Record 27 of Set 5 | puerto ayora
# Processing Record 28 of Set 5 | temerloh
# Processing Record 29 of Set 5 | luganville
# Processing Record 30 of Set 5 | airai
# Processing Record 31 of Set 5 | provideniya
# Processing Record 32 of Set 5 | ennis
# Processing Record 33 of Set 5 | burlington
# Processing Record 34 of Set 5 | charters towers
# Processing Record 35 of Set 5 | ayan
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | sabang
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | raudeberg
# Processing Record 40 of Set 5 | juneau
# Processing Record 41 of Set 5 | calamar
# Processing Record 42 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 5 | naze
# Processing Record 44 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 5 | katsuura
# Processing Record 46 of Set 5 | sao joao da barra
# Processing Record 47 of Set 5 | dakar
# Processing Record 48 of Set 5 | kirakira
# Processing Record 49 of Set 5 | puerto colombia
# Processing Record 50 of Set 5 | kizilskoye
# Processing Record 1 of Set 6 | bikaner
# Processing Record 2 of Set 6 | yar-sale
# Processing Record 3 of Set 6 | geraldton
# Processing Record 4 of Set 6 | ixtapa
# Processing Record 5 of Set 6 | kristiinankaupunki
# Processing Record 6 of Set 6 | port hedland
# Processing Record 7 of Set 6 | iranshahr
# Processing Record 8 of Set 6 | mogadishu
# Processing Record 9 of Set 6 | beringovskiy
# Processing Record 10 of Set 6 | fort saint james
# Processing Record 11 of Set 6 | laguna
# Processing Record 12 of Set 6 | north platte
# Processing Record 13 of Set 6 | narok
# Processing Record 14 of Set 6 | ankang
# Processing Record 15 of Set 6 | kankaanpaa
# Processing Record 16 of Set 6 | broome
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | basoko
# Processing Record 19 of Set 6 | cidreira
# Processing Record 20 of Set 6 | koumac
# Processing Record 21 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 22 of Set 6 | kununurra
# Processing Record 23 of Set 6 | hualmay
# Processing Record 24 of Set 6 | katobu
# Processing Record 25 of Set 6 | san quintin
# Processing Record 26 of Set 6 | gweta
# Processing Record 27 of Set 6 | brookhaven
# Processing Record 28 of Set 6 | vardo
# Processing Record 29 of Set 6 | merced
# Processing Record 30 of Set 6 | lingdong
# Processing Record 31 of Set 6 | chunhuhub
# Processing Record 32 of Set 6 | minab
# Processing Record 33 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 6 | nemuro
# Processing Record 35 of Set 6 | puerto ayacucho
# Processing Record 36 of Set 6 | neyshabur
# Processing Record 37 of Set 6 | sechura
# Processing Record 38 of Set 6 | beloha
# Processing Record 39 of Set 6 | ahipara
# Processing Record 40 of Set 6 | huarmey
# Processing Record 41 of Set 6 | hurricane
# Processing Record 42 of Set 6 | ararat
# Processing Record 43 of Set 6 | san vicente
# Processing Record 44 of Set 6 | erdenet
# Processing Record 45 of Set 6 | itarema
# Processing Record 46 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 6 | faya
# Processing Record 48 of Set 6 | bardiyah
# Processing Record 49 of Set 6 | nishihara
# Processing Record 50 of Set 6 | great falls
# Processing Record 1 of Set 7 | abatskoye
# Processing Record 2 of Set 7 | pomezia
# Processing Record 3 of Set 7 | hamilton
# Processing Record 4 of Set 7 | lavrentiya
# Processing Record 5 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 7 | svetlyy
# Processing Record 7 of Set 7 | jijiga
# Processing Record 8 of Set 7 | talnakh
# Processing Record 9 of Set 7 | toktogul
# Processing Record 10 of Set 7 | ler
# Processing Record 11 of Set 7 | saint-pierre
# Processing Record 12 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 7 | ryotsu
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | kaseda
# Processing Record 17 of Set 7 | gladstone
# Processing Record 18 of Set 7 | maragogi
# Processing Record 19 of Set 7 | rio tuba
# Processing Record 20 of Set 7 | pisco
# Processing Record 21 of Set 7 | nioro
# Processing Record 22 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 7 | umba
# Processing Record 24 of Set 7 | bilma
# Processing Record 25 of Set 7 | fare
# Processing Record 26 of Set 7 | bo
# City not found. Skipping...
# Processing Record 27 of Set 7 | auki
# Processing Record 28 of Set 7 | acapulco
# Processing Record 29 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 7 | tolaga bay
# Processing Record 31 of Set 7 | mirnyy
# Processing Record 32 of Set 7 | klaksvik
# Processing Record 33 of Set 7 | nelson bay
# Processing Record 34 of Set 7 | narsaq
# Processing Record 35 of Set 7 | candelaria
# Processing Record 36 of Set 7 | pitimbu
# Processing Record 37 of Set 7 | butere
# Processing Record 38 of Set 7 | tabas
# Processing Record 39 of Set 7 | colquiri
# Processing Record 40 of Set 7 | isangel
# Processing Record 41 of Set 7 | cap-aux-meules
# Processing Record 42 of Set 7 | progreso
# Processing Record 43 of Set 7 | gunjur
# Processing Record 44 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 7 | andarab
# City not found. Skipping...
# Processing Record 46 of Set 7 | vitoria da conquista
# Processing Record 47 of Set 7 | otorohanga
# Processing Record 48 of Set 7 | santarem
# Processing Record 49 of Set 7 | ostersund
# Processing Record 50 of Set 7 | rahuri
# Processing Record 1 of Set 8 | kruisfontein
# Processing Record 2 of Set 8 | port lincoln
# Processing Record 3 of Set 8 | antofagasta
# Processing Record 4 of Set 8 | sept-iles
# Processing Record 5 of Set 8 | maumere
# Processing Record 6 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 8 | northam
# Processing Record 8 of Set 8 | simpang
# Processing Record 9 of Set 8 | borba
# Processing Record 10 of Set 8 | urdoma
# Processing Record 11 of Set 8 | sakaraha
# Processing Record 12 of Set 8 | totolapa
# Processing Record 13 of Set 8 | camacha
# Processing Record 14 of Set 8 | jiblah
# Processing Record 15 of Set 8 | sharqpur
# Processing Record 16 of Set 8 | olinda
# Processing Record 17 of Set 8 | shaowu
# Processing Record 18 of Set 8 | sibolga
# Processing Record 19 of Set 8 | zaykovo
# Processing Record 20 of Set 8 | dibaya
# City not found. Skipping...
# Processing Record 21 of Set 8 | shitanjing
# Processing Record 22 of Set 8 | pospelikha
# Processing Record 23 of Set 8 | uzunovo
# Processing Record 24 of Set 8 | lima
# Processing Record 25 of Set 8 | cap malheureux
# Processing Record 26 of Set 8 | saint-paul
# Processing Record 27 of Set 8 | bubaque
# Processing Record 28 of Set 8 | rosita
# Processing Record 29 of Set 8 | tonj
# Processing Record 30 of Set 8 | rach gia
# Processing Record 31 of Set 8 | saint-augustin
# Processing Record 32 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 8 | kalaleh
# Processing Record 34 of Set 8 | luderitz
# Processing Record 35 of Set 8 | kankan
# Processing Record 36 of Set 8 | corozal
# Processing Record 37 of Set 8 | petrolina
# Processing Record 38 of Set 8 | portland
# Processing Record 39 of Set 8 | aklavik
# Processing Record 40 of Set 8 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 8 | haines junction
# Processing Record 42 of Set 8 | cape elizabeth
# City not found. Skipping...
# Processing Record 43 of Set 8 | diego de almagro
# Processing Record 44 of Set 8 | bambanglipuro
# Processing Record 45 of Set 8 | salinopolis
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | ribeira grande
# Processing Record 48 of Set 8 | kodiak
# Processing Record 49 of Set 8 | nivala
# Processing Record 50 of Set 8 | jacareacanga
# Processing Record 1 of Set 9 | hami
# Processing Record 2 of Set 9 | atar
# Processing Record 3 of Set 9 | batsfjord
# Processing Record 4 of Set 9 | ranau
# Processing Record 5 of Set 9 | khovu-aksy
# Processing Record 6 of Set 9 | corn island
# Processing Record 7 of Set 9 | marsh harbour
# Processing Record 8 of Set 9 | kamenka
# Processing Record 9 of Set 9 | impfondo
# Processing Record 10 of Set 9 | cherskiy
# Processing Record 11 of Set 9 | quatre cocos
# Processing Record 12 of Set 9 | iquitos
# Processing Record 13 of Set 9 | matadi
# Processing Record 14 of Set 9 | sao joao del rei
# Processing Record 15 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 16 of Set 9 | qandala
# Processing Record 17 of Set 9 | bowen
# Processing Record 18 of Set 9 | emba
# Processing Record 19 of Set 9 | seddon
# Processing Record 20 of Set 9 | anadyr
# Processing Record 21 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 22 of Set 9 | bengbu
# Processing Record 23 of Set 9 | muzaffarabad
# Processing Record 24 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 25 of Set 9 | santa cruz
# Processing Record 26 of Set 9 | bentiu
# Processing Record 27 of Set 9 | praya
# Processing Record 28 of Set 9 | guerrero negro
# Processing Record 29 of Set 9 | vanimo
# Processing Record 30 of Set 9 | stettler
# Processing Record 31 of Set 9 | visby
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | aneho
# Processing Record 34 of Set 9 | tingo maria
# Processing Record 35 of Set 9 | grindavik
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | agadez
# Processing Record 38 of Set 9 | kavieng
# Processing Record 39 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 9 | lanxi
# Processing Record 41 of Set 9 | tadine
# Processing Record 42 of Set 9 | ndiekro
# City not found. Skipping...
# Processing Record 43 of Set 9 | berbera
# Processing Record 44 of Set 9 | arona
# Processing Record 45 of Set 9 | cervo
# Processing Record 46 of Set 9 | carutapera
# Processing Record 47 of Set 9 | henties bay
# Processing Record 48 of Set 9 | polovinnoye
# Processing Record 49 of Set 9 | kailua
# Processing Record 50 of Set 9 | kachug
# Processing Record 1 of Set 10 | buraydah
# Processing Record 2 of Set 10 | djibo
# Processing Record 3 of Set 10 | bekhteyevka
# Processing Record 4 of Set 10 | bahia honda
# Processing Record 5 of Set 10 | florianopolis
# Processing Record 6 of Set 10 | prainha
# Processing Record 7 of Set 10 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 8 of Set 10 | yulara
# Processing Record 9 of Set 10 | sarata
# Processing Record 10 of Set 10 | lundazi
# Processing Record 11 of Set 10 | champerico
# Processing Record 12 of Set 10 | vierzon
# Processing Record 13 of Set 10 | mrkonjic grad
# Processing Record 14 of Set 10 | gimli
# Processing Record 15 of Set 10 | buin
# Processing Record 16 of Set 10 | dingle
# Processing Record 17 of Set 10 | buala
# Processing Record 18 of Set 10 | akcakoca
# Processing Record 19 of Set 10 | sidrolandia
# Processing Record 20 of Set 10 | adre
# Processing Record 21 of Set 10 | turukhansk
# Processing Record 22 of Set 10 | lethem
# Processing Record 23 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 10 | prince rupert
# Processing Record 25 of Set 10 | vila do maio
# Processing Record 26 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 10 | ariquemes
# Processing Record 28 of Set 10 | podporozhye
# Processing Record 29 of Set 10 | gorontalo
# Processing Record 30 of Set 10 | manzanillo
# Processing Record 31 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 10 | gympie
# Processing Record 33 of Set 10 | khani
# Processing Record 34 of Set 10 | kahului
# Processing Record 35 of Set 10 | nangomba
# Processing Record 36 of Set 10 | koster
# Processing Record 37 of Set 10 | abay
# Processing Record 38 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 10 | ena
# Processing Record 40 of Set 10 | riyadh
# Processing Record 41 of Set 10 | natchez
# Processing Record 42 of Set 10 | daru
# Processing Record 43 of Set 10 | conway
# Processing Record 44 of Set 10 | martil
# Processing Record 45 of Set 10 | aksarka
# Processing Record 46 of Set 10 | urengoy
# Processing Record 47 of Set 10 | sovetskiy
# Processing Record 48 of Set 10 | canavieiras
# Processing Record 49 of Set 10 | xai-xai
# Processing Record 50 of Set 10 | canoa
# Processing Record 1 of Set 11 | elko
# Processing Record 2 of Set 11 | yambio
# Processing Record 3 of Set 11 | lagoa
# Processing Record 4 of Set 11 | kragero
# Processing Record 5 of Set 11 | tarabuco
# Processing Record 6 of Set 11 | cururupu
# Processing Record 7 of Set 11 | secunda
# Processing Record 8 of Set 11 | parambu
# Processing Record 9 of Set 11 | eisenberg
# Processing Record 10 of Set 11 | ust-kulom
# Processing Record 11 of Set 11 | erzin
# Processing Record 12 of Set 11 | slave lake
# Processing Record 13 of Set 11 | gubkin
# Processing Record 14 of Set 11 | dhemaji
# Processing Record 15 of Set 11 | falun
# Processing Record 16 of Set 11 | ketchikan
# Processing Record 17 of Set 11 | namibe
# Processing Record 18 of Set 11 | tucurui
# Processing Record 19 of Set 11 | jiangmen
# Processing Record 20 of Set 11 | orsha
# Processing Record 21 of Set 11 | kudahuvadhoo
# Processing Record 22 of Set 11 | doha
# Processing Record 23 of Set 11 | flin flon
# Processing Record 24 of Set 11 | manchenky
# Processing Record 25 of Set 11 | lufilufi
# Processing Record 26 of Set 11 | yumen
# Processing Record 27 of Set 11 | nacala
# Processing Record 28 of Set 11 | zhongxing
# Processing Record 29 of Set 11 | coetupo
# City not found. Skipping...
# Processing Record 30 of Set 11 | nouadhibou
# Processing Record 31 of Set 11 | kenora
# Processing Record 32 of Set 11 | abha
# Processing Record 33 of Set 11 | batemans bay
# Processing Record 34 of Set 11 | hay river
# Processing Record 35 of Set 11 | los llanos de aridane
# Processing Record 36 of Set 11 | koson
# Processing Record 37 of Set 11 | kangasala
# Processing Record 38 of Set 11 | mpulungu
# Processing Record 39 of Set 11 | qaqortoq
# Processing Record 40 of Set 11 | gumushane
# City not found. Skipping...
# Processing Record 41 of Set 11 | anchorage
# Processing Record 42 of Set 11 | qui nhon
# Processing Record 43 of Set 11 | sobolevo
# Processing Record 44 of Set 11 | kloulklubed
# Processing Record 45 of Set 11 | aykhal
# Processing Record 46 of Set 11 | mombetsu
# Processing Record 47 of Set 11 | nicoya
# Processing Record 48 of Set 11 | clarence town
# Processing Record 49 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 11 | amahai
# Processing Record 1 of Set 12 | mayo
# Processing Record 2 of Set 12 | pacific grove
# Processing Record 3 of Set 12 | comodoro rivadavia
# Processing Record 4 of Set 12 | trairi
# Processing Record 5 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 12 | charlestown
# Processing Record 7 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 8 of Set 12 | jeremie
# Processing Record 9 of Set 12 | kieta
# Processing Record 10 of Set 12 | asau
# Processing Record 11 of Set 12 | izumo
# Processing Record 12 of Set 12 | mareeba
# Processing Record 13 of Set 12 | half moon bay
# Processing Record 14 of Set 12 | poronaysk
# Processing Record 15 of Set 12 | alta floresta
# Processing Record 16 of Set 12 | pevek
# Processing Record 17 of Set 12 | terrace bay
# Processing Record 18 of Set 12 | kingori
# Processing Record 19 of Set 12 | santa maria
# Processing Record 20 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 12 | jabinyanah
# Processing Record 22 of Set 12 | bathsheba
# Processing Record 23 of Set 12 | nokaneng
# Processing Record 24 of Set 12 | dekar
# Processing Record 25 of Set 12 | matay
# Processing Record 26 of Set 12 | le moule
# Processing Record 27 of Set 12 | kysyl-syr
# Processing Record 28 of Set 12 | mirebalais
# Processing Record 29 of Set 12 | letlhakane
# Processing Record 30 of Set 12 | balaghat
# Processing Record 31 of Set 12 | barcelos
# Processing Record 32 of Set 12 | vieques
# Processing Record 33 of Set 12 | codrington
# Processing Record 34 of Set 12 | goshen
# Processing Record 35 of Set 12 | maromitsa
# Processing Record 36 of Set 12 | tilichiki
# Processing Record 37 of Set 12 | salinas
# Processing Record 38 of Set 12 | byron bay
# Processing Record 39 of Set 12 | mazagao
# Processing Record 40 of Set 12 | gravdal
# Processing Record 41 of Set 12 | orzhytsya
# Processing Record 42 of Set 12 | ibra
# Processing Record 43 of Set 12 | cyangugu
# Processing Record 44 of Set 12 | san patricio
# Processing Record 45 of Set 12 | bogovarovo
# Processing Record 46 of Set 12 | natal
# Processing Record 47 of Set 12 | dubbo
# Processing Record 48 of Set 12 | kibala
# Processing Record 49 of Set 12 | dalaba
# Processing Record 50 of Set 12 | plouzane
# Processing Record 1 of Set 13 | acari
# Processing Record 2 of Set 13 | blitar
# Processing Record 3 of Set 13 | calahorra
# Processing Record 4 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 5 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 6 of Set 13 | makakilo city
# Processing Record 7 of Set 13 | alcudia
# Processing Record 8 of Set 13 | puerto lopez
# Processing Record 9 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 13 | opuwo
# Processing Record 11 of Set 13 | preston
# Processing Record 12 of Set 13 | libertador general san martin
# Processing Record 13 of Set 13 | hofn
# Processing Record 14 of Set 13 | mount isa
# Processing Record 15 of Set 13 | vizinga
# Processing Record 16 of Set 13 | mandalgovi
# Processing Record 17 of Set 13 | rangapara
# Processing Record 18 of Set 13 | muriwai beach
# Processing Record 19 of Set 13 | tambovka
# Processing Record 20 of Set 13 | dosso
# Processing Record 21 of Set 13 | kibara
# Processing Record 22 of Set 13 | vitim
# Processing Record 23 of Set 13 | meitingen
# Processing Record 24 of Set 13 | beira
# Processing Record 25 of Set 13 | rorvik
# Processing Record 26 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 13 | uray
# Processing Record 28 of Set 13 | portel
# Processing Record 29 of Set 13 | vestmanna
# Processing Record 30 of Set 13 | binzhou
# Processing Record 31 of Set 13 | alofi
# Processing Record 32 of Set 13 | tharad
# Processing Record 33 of Set 13 | jesus maria
# Processing Record 34 of Set 13 | dyakonovo
# City not found. Skipping...
# Processing Record 35 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 13 | port shepstone
# Processing Record 37 of Set 13 | inuvik
# Processing Record 38 of Set 13 | chivay
# Processing Record 39 of Set 13 | naron
# Processing Record 40 of Set 13 | naryan-mar
# Processing Record 41 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 42 of Set 13 | nagato
# Processing Record 43 of Set 13 | acajutla
# Processing Record 44 of Set 13 | havelock
# Processing Record 45 of Set 13 | virapandi
# City not found. Skipping...
# Processing Record 46 of Set 13 | bahia blanca
# Processing Record 47 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 13 | lulea
# Processing Record 50 of Set 13 | khandbari
# Processing Record 1 of Set 14 | castro daire
# Processing Record 2 of Set 14 | vredendal
# Processing Record 3 of Set 14 | koundara
# Processing Record 4 of Set 14 | gobabis
# Processing Record 5 of Set 14 | bonthe
# Processing Record 6 of Set 14 | metro
# Processing Record 7 of Set 14 | porto novo
# Processing Record 8 of Set 14 | batasan
# Processing Record 9 of Set 14 | jiwani
# Processing Record 10 of Set 14 | havoysund
# Processing Record 11 of Set 14 | ati
# Processing Record 12 of Set 14 | poum
# Processing Record 13 of Set 14 | la rioja
# Processing Record 14 of Set 14 | gamba
# Processing Record 15 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 14 | necochea
# Processing Record 17 of Set 14 | tenenkou
# Processing Record 18 of Set 14 | pundaguitan
# Processing Record 19 of Set 14 | chaiya
# Processing Record 20 of Set 14 | north bend
# Processing Record 21 of Set 14 | mamallapuram
# Processing Record 22 of Set 14 | sakti
# Processing Record 23 of Set 14 | varna
# Processing Record 24 of Set 14 | ust-kut
# Processing Record 25 of Set 14 | tateyama
# Processing Record 26 of Set 14 | mayumba
# Processing Record 27 of Set 14 | petawawa
# Processing Record 28 of Set 14 | porto san giorgio
# Processing Record 29 of Set 14 | tukrah
# Processing Record 30 of Set 14 | ormara
# Processing Record 31 of Set 14 | balakhninskiy
# Processing Record 32 of Set 14 | husavik
# Processing Record 33 of Set 14 | ellisras
# Processing Record 34 of Set 14 | nalobikha
# Processing Record 35 of Set 14 | te anau
# Processing Record 36 of Set 14 | jalapa
# Processing Record 37 of Set 14 | la ronge
# Processing Record 38 of Set 14 | zhangye
# Processing Record 39 of Set 14 | akyab
# Processing Record 40 of Set 14 | dhadar
# Processing Record 41 of Set 14 | cruzeiro do sul
# Processing Record 42 of Set 14 | angra
# City not found. Skipping...
# Processing Record 43 of Set 14 | basco
# Processing Record 44 of Set 14 | erdemli
# Processing Record 45 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 14 | celestun
# Processing Record 47 of Set 14 | maningrida
# Processing Record 48 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 14 | saint anthony
# Processing Record 50 of Set 14 | bandarbeyla
# Processing Record 1 of Set 15 | muros
# Processing Record 2 of Set 15 | hanstholm
# Processing Record 3 of Set 15 | morondava
# Processing Record 4 of Set 15 | zykovo
# Processing Record 5 of Set 15 | actopan
# Processing Record 6 of Set 15 | barstow
# Processing Record 7 of Set 15 | huacho
# Processing Record 8 of Set 15 | fort nelson
# Processing Record 9 of Set 15 | puerto baquerizo moreno
# Processing Record 10 of Set 15 | imeni poliny osipenko
# Processing Record 11 of Set 15 | balsas
# Processing Record 12 of Set 15 | coihaique
# Processing Record 13 of Set 15 | kitimat
# Processing Record 14 of Set 15 | amazar
# Processing Record 15 of Set 15 | sisimiut
# Processing Record 16 of Set 15 | acahay
# Processing Record 17 of Set 15 | bayanday
# Processing Record 18 of Set 15 | yining
# Processing Record 19 of Set 15 | noboribetsu
# Processing Record 20 of Set 15 | chifeng
# Processing Record 21 of Set 15 | barretos
# Processing Record 22 of Set 15 | dzilam gonzalez
# Processing Record 23 of Set 15 | urubicha
# Processing Record 24 of Set 15 | kalmunai
# Processing Record 25 of Set 15 | concepcion
# Processing Record 26 of Set 15 | brownsville
# Processing Record 27 of Set 15 | bundaberg
# Processing Record 28 of Set 15 | matara
# Processing Record 29 of Set 15 | fort walton beach
# Processing Record 30 of Set 15 | mitikas
# Processing Record 31 of Set 15 | berezovyy
# Processing Record 32 of Set 15 | grand gaube
# Processing Record 33 of Set 15 | caravelas
# Processing Record 34 of Set 15 | vostok
# Processing Record 35 of Set 15 | tungor
# Processing Record 36 of Set 15 | bystryy istok
# Processing Record 37 of Set 15 | salisbury
# Processing Record 38 of Set 15 | araouane
# Processing Record 39 of Set 15 | ozerne
# Processing Record 40 of Set 15 | sarkand
# Processing Record 41 of Set 15 | nuuk
# Processing Record 42 of Set 15 | isilkul
# Processing Record 43 of Set 15 | ola
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City       Description      Lat       Lng  Max Temp  Humidity  \
# 0          Rikitea        light rain -23.1203 -134.9692     73.44        75
# 1           Hobart        few clouds -42.8794  147.3294     48.06        64
# 2        Jamestown         clear sky  42.0970  -79.2353     76.59        54
# 3            Guane     broken clouds  22.2025  -84.0875     80.73        74
# 4  Arraial Do Cabo        few clouds -22.9661  -42.0278     71.24        84
# 5    Alice Springs  scattered clouds -23.7000  133.8833     60.35        27
# 6      New Norfolk  scattered clouds -42.7826  147.0587     47.70        50
# 7        Saskylakh   overcast clouds  71.9167  114.0833     60.66        88
# 8           Barrow   overcast clouds  71.2906 -156.7887     33.82       100
# 9            Kapaa     broken clouds  22.0752 -159.3190     84.18        77
#
#    Cloudiness  Wind Speed Country                 Date
# 0           8       20.76      PF  2022-07-29 01:15:36
# 1          20       14.97      AU  2022-07-29 01:15:04
# 2           0        8.05      US  2022-07-29 01:15:37
# 3          77        4.97      CU  2022-07-29 01:15:37
# 4          13       25.50      BR  2022-07-29 01:15:38
# 5          32       12.66      AU  2022-07-29 01:15:38
# 6          31        7.70      AU  2022-07-29 01:15:39
# 7         100        5.17      RU  2022-07-29 01:15:39
# 8         100       14.97      US  2022-07-29 01:15:40
# 9          75        8.05      US  2022-07-29 01:12:49

# %%
new_column_order= ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0          Rikitea      PF  2022-07-29 01:15:36 -23.1203 -134.9692     73.44
# 1           Hobart      AU  2022-07-29 01:15:04 -42.8794  147.3294     48.06
# 2        Jamestown      US  2022-07-29 01:15:37  42.0970  -79.2353     76.59
# 3            Guane      CU  2022-07-29 01:15:37  22.2025  -84.0875     80.73
# 4  Arraial Do Cabo      BR  2022-07-29 01:15:38 -22.9661  -42.0278     71.24
#
#    Humidity  Cloudiness  Wind Speed    Description
# 0        75           8       20.76     light rain
# 1        64          20       14.97     few clouds
# 2        54           0        8.05      clear sky
# 3        74          77        4.97  broken clouds
# 4        84          13       25.50     few clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export the City_Data into CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
